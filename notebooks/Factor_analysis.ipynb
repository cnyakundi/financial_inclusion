# %% [markdown]
# <a href="https://colab.research.google.com/github/cnyakundi/financial_inclusion/blob/master/notebooks/Factor_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Multivariate Analysis with Python: Factor Analysis

# %% [markdown]
# ## Loading our libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Previewing the dataset

# %%
df=pd.read_csv('FinScope Tanzania 2017_27092017.csv')

df
# Out:
#        SbjNum  Region  Region_Code  District  ...   MZ  fasx  overlapx  tot
# 0    48475424       5            5        34  ...  1.0   1.0       7.0  1.0
# 1    47118466       4            4        24  ...  1.0   2.0       6.0  1.0
# 2    47441546      19           19       119  ...  1.0   2.0       6.0  1.0
# 3    46902140      11           11        70  ...  1.0   1.0       7.0  1.0
# 4    46894875      19           19       123  ...  1.0   1.0       7.0  1.0
# ..        ...     ...          ...       ...  ...  ...   ...       ...  ...
# 657  48428478      13           13        79  ...  1.0   2.0       6.0  1.0
# 658  47777663      11           11        68  ...  1.0   2.0       6.0  1.0
# 659  46814783       9            9        55  ...  1.0   2.0       6.0  1.0
# 660  47987697      12           12        75  ...  1.0   2.0       6.0  1.0
# 661  49084137      21           21       135  ...  NaN   NaN       NaN  NaN
#
# [662 rows x 1211 columns]

# %%
# Previewing the dataset columns

df.columns
# Out:
# Index(['SbjNum', 'Region', 'Region_Code', 'District', 'District_Code', 'Ward',
#        'Ward_Code', 'Village_Code', 'EA', 'UEA_Code',
#        ...
#        'PPIScore', 'PPI_Category', 'IncomeMain', 'BusO', 'Farmers', 'RU', 'MZ',
#        'fasx', 'overlapx', 'tot'],
#       dtype='object', length=1211)

# %% [markdown]
#  ### Dropping missing values rows

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Checking the datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 661 entries, 0 to 660
# Columns: 1211 entries, SbjNum to tot
# dtypes: float64(565), int64(505), object(141)
# memory usage: 6.1+ MB

# %% [markdown]
# ### Previewing our dataset

# %%
df.head()
# Out:
#      SbjNum  Region  Region_Code  District  ...   MZ  fasx  overlapx  tot
# 0  48475424       5            5        34  ...  1.0   1.0       7.0  1.0
# 1  47118466       4            4        24  ...  1.0   2.0       6.0  1.0
# 2  47441546      19           19       119  ...  1.0   2.0       6.0  1.0
# 3  46902140      11           11        70  ...  1.0   1.0       7.0  1.0
# 4  46894875      19           19       123  ...  1.0   1.0       7.0  1.0
#
# [5 rows x 1211 columns]

# %% [markdown]
# ### Installing factor analyzer

# %%
# !pip install factor_analyzer==0.2.3

# %%
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity

chi_square_value,p_value=calculate_bartlett_sphericity(df)
chi_square_value, p_value
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/linalg/linalg.py:2159: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# (nan, nan)

# %%
from factor_analyzer.factor_analyzer import calculate_kmo

kmo_all,kmo_model=calculate_kmo(df)

# %%
from factor_analyzer.factor_analyzer import FactorAnalyzer

# Creating factor analysis object and perform factor analysis
fa = FactorAnalyzer()
fa.analyze(df, 25, rotation=None)

# Checking the Eigenvalues
ev, v = fa.get_eigenvalues()
ev
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-7bce2b1d0ff4> in <module>()
#       3 # Creating factor analysis object and perform factor analysis
#       4 fa = FactorAnalyzer()
# ----> 5 fa.analyze(df, 25, rotation=None)
#       6
#       7 # Checking the Eigenvalues
#
# /usr/local/lib/python3.7/dist-packages/factor_analyzer/factor_analyzer.py in analyze(self, data, n_factors, rotation, method, use_smc, bounds, normalize, impute, **kwargs)
#     743                                             use_smc,
#     744                                             bounds,
# --> 745                                             method)
#     746
#     747         # only used if we do an oblique rotations
#
# /usr/local/lib/python3.7/dist-packages/factor_analyzer/factor_analyzer.py in fit_factor_analysis(self, data, n_factors, use_smc, bounds, method)
# ...

# %%
plt.scatter(range(1,df.shape[1]+1),ev)
plt.plot(range(1,df.shape[1]+1),ev)
plt.title('Scree Plot')
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c0c6c530b1fd> in <module>()
# ----> 1 plt.scatter(range(1,df.shape[1]+1),ev)
#       2 plt.plot(range(1,df.shape[1]+1),ev)
#       3 plt.title('Scree Plot')
#       4 plt.xlabel('Factors')
#       5 plt.ylabel('Eigenvalue')
#
# NameError: name 'ev' is not defined
